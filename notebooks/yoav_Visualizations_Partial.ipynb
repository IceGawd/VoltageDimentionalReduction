# %%
import sys
import os
sys.path.append(os.path.abspath("../clean_code/"))
sys.path
# Out:
# ['/Users/yoavfreund/opt/anaconda3/lib/python3.8/site-packages/,/Users/yoavfreund/python_packages',
#  '',
#  '/usr/local/lib/python2.7/site-packages',
#  '/usr/local/Caskroom/miniforge/base/envs/faiss_env/lib/python39.zip',
#  '/usr/local/Caskroom/miniforge/base/envs/faiss_env/lib/python3.9',
#  '/usr/local/Caskroom/miniforge/base/envs/faiss_env/lib/python3.9/lib-dynload',
#  '/usr/local/Caskroom/miniforge/base/envs/faiss_env/lib/python3.9/site-packages',
#  '/Users/yoavfreund/projects/VoltageDimentionalReduction/clean_code']

# %%
# %cd ../clean_code/
# Out:
# /Users/yoavfreund/projects/VoltageDimentionalReduction/clean_code

# %%
from Visualization import generalVisualization
from Visualization import mnistVisuals
from Visualization import visualHelpers
from Visualization.mnistVisuals import plot_landmark_subset
from Utilities import config
import pickle
import select_landmarks_MI
import importlib
import voltagemap
import main
import matplotlib.pyplot as plt
import numpy as np

# %%
#load data from the pickle file
with open('../../Voltage_Temp/Results/mnist/saved_data7,10,14,15,16.pkl', 'rb') as f:
    data= pickle.load(f)

# %%
data.keys()
# Out:
# dict_keys(['majority_labels', 'label_counts', 'all_voltages', 'centroids', 'voltage_map'])

# %%
voltages= data['voltage_map']
centroids= data['centroids']


label_counts= data['label_counts']
label_counts[1].most_common()[0][1]
# !ls -l ../../Voltage_Temp/Scatter_Plots/
# Out:
# total 0
# drwxr-xr-x  12 yoavfreund  staff  384 Aug 23 15:07 glove
# drwxr-xr-x@  5 yoavfreund  staff  160 Jul 23 13:08 glove2000
# drwxr-xr-x@  8 yoavfreund  staff  256 Aug 23 15:48 mnist

# %%
focus_on = np.array(range(10))

"""
Visualizes MNIST digits in 2D space using voltage-based embeddings reduced by PCA or MDS.

Each point in the embedding is rendered as a translucent RGB digit image colored by its label.
Landmark points (voltage = 1) are optionally scaled up to highlight their influence.

"""

transformation="pca"; landmarkSize=3; alpha_actual=1; percent_size=0.02; out_file=None; log_transform=True; num_labels=10

points = voltages.voltage_array()

transformed_points = visualHelpers.transform(points, "pca")

plots_dir='../../Voltage_Temp/Scatter_Plots/mnist7,10,14,15,16/'
','.join([str(x) for x in list(focus_on)])
out_plot=plots_dir+','.join([str(x) for x in list(focus_on)])+'.png'


from Visualization.mnistVisuals import plot_landmark_subset
print(f"centroids.shape={centroids.shape}, points.shape={points.shape}")
plot_landmark_subset(points, centroids, label_counts, focus_on, percent_size=percent_size, 
                     alpha_actual=alpha_actual, out_file=out_plot,element='digit')
# Out:
# centroids.shape=(100, 20), points.shape=(100, 10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 24
#      22 from Visualization.mnistVisuals import plot_landmark_subset
#      23 print(f"centroids.shape={centroids.shape}, points.shape={points.shape}")
# ---> 24 plot_landmark_subset(points, centroids, label_counts, focus_on, percent_size=percent_size,
#      25                      alpha_actual=alpha_actual, out_file=out_plot,element='digit')
#
# File ~/projects/VoltageDimentionalReduction/clean_code/Visualization/mnistVisuals.py:234, in plot_landmark_subset(points, centroids, label_counts, focus_on, log_transform, transformation, **kwargs)
#     231 # perform the dimensionality reduction:
#     232 transformed_points = visualHelpers.transform(points, transformation)
# --> 234 scatter_plot(points, transformed_points, centroids, focus_on, labels, reverse_dict_labels, **kwargs)
#
# File ~/projects/VoltageDimentionalReduction/clean_code/Visualization/mnistVisuals.py:160, in scatter_plot(points, transformed_points, data, focus_on, labels, reverse_dict_labels, percent_size, alpha_actual, out_file, element)
#     156 if element=="digit":
#     157
#     158 	# Create RGBA image of mnist digit with alpha mask
#     159 	rgb_image = np.zeros((28, 28, 4))
# --> 160 	alpha_mask = np.clip(data[i].reshape(28, 28), 0, 255) / 255  #The mask defines the silhouette of the digit
#     162 	rgb_image[..., 0:3] = color
#     163 	rgb_image[..., 3] = alpha_mask * alpha_actual  # Alpha from pixel intensity
#
# ValueError: cannot reshape array of size 20 into shape (28,28)

# %%
plt.hist(np.min(points,axis=1));

# %%
points.shape
# Out:
# (1000, 20)
