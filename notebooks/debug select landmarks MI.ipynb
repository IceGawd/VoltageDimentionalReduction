# %%
# !ls -l ../../Voltage_Temp/Results/voltage_map.npy
# Out:
# -rw-r--r--  1 yoavfreund  staff  11289811 Jul 12 14:12 ../../Voltage_Temp/Results/voltage_map.npy

# %%
# %cd ../clean_code/
# Out:
# /Users/yoavfreund/projects/VoltageDimentionalReduction/clean_code

# %%
import voltagemap   
import numpy as np
from Utilities import config
from copy import copy
# %cd ..
# Out:
# /Users/yoavfreund/projects/VoltageDimentionalReduction

# %%
import pickle
with open('../Voltage_Temp/Results/voltage_map.npy','rb') as f:
    Data = pickle.load(f)

# %%
Data.keys()
from copy import copy
voltage_map = copy(Data['all_voltages'])
i=10
j=20

# %%
voltage_matrix = np.stack([voltage_map.entries[k][1] for k in (list(range(i))+[j]) ])  # Stack the voltages of the current landmarks and the new candidate landmark

# %%
voltage_matrix.shape
# Out:
# (11, 1000)

# %%
len(voltage_map.entries[10])
# Out:
# 3

# %%
np.exp(5.6), np.exp(5.8), np.exp(6.96)
# Out:
# (270.42640742615254, 330.2995599096486, 1053.6335572423195)

# %%
np.log(1000)
# Out:
# 6.907755278982137
