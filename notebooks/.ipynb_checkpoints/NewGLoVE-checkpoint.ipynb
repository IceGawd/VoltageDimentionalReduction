# %%
import sys
import os
sys.path.append(os.path.abspath("../clean_code/"))

# %%
from Visualization import generalVisualization
from Visualization import gloveVisuals
from Visualization import visualHelpers
from Utilities import config

import pickle
import select_landmarks_MI
import importlib
import voltagemap
import setofpoints
import main
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.datasets import fetch_openml

# %%
config.params['file_path']= '../../Voltage_Data/glove/glove.6B.300d.txt'
config.params['split_char']= ' '
config.params['normalize_vecs'] = True

config.params['max_centroids']= 1000
config.params['init_size']= 5000
config.params['batch_size']= 1000
config.params['kmeans_output']= '../../Voltage_Temp/Results/glove.npy'
config.params['k']=10
config.params['r']=1
config.params['alpha']=0.1
config.params['equalize_centroids']=False
config.params['NoOfLandmarks']=10
config.params['DepthOfLandmarkSearch']=100

# %%
data_to_save = main.main()
# Out:
# Read 2000 vectors
# no of parts= 1
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_to_save = main.main()
#
# File ~/Documents/python/VoltageDimentionalReduction/clean_code/main.py:41, in main(filepath, save)
#      39 timer=Timer()
#      40 # generate centroids using streaming k-means
# ---> 41 points, counters, majority_labels, label_counts, rms=kmeans.Streaming_Kmeans(filepath)
#      42 timer.mark("Streaming K-means completed")
#      44 #X=np.stack(points)
#      45 #y= np.array(label_counts)
#      46
#      47 # define set of set of centroids
#
# File ~/Documents/python/VoltageDimentionalReduction/clean_code/kmeans.py:187, in Streaming_Kmeans(filepath)
#     185 total_needed = config.params['init_size']
#     186 collected = 0
# --> 187 for vectors, _ in reader.stream_batches(config.params['batch_size']):
#     188     if d is None:
#     189         d = vectors.shape[1]
#
# File ~/Documents/python/VoltageDimentionalReduction/clean_code/Utilities/reader.py:242, in Reader.stream_batches(self, batch_size)
#     240 labels = []
#     241 for _ in range(batch_size):
# --> 242 	label, vec = readvec(self.file, is_binary=(self.file_type == 'npy'))
#     243 	if vec is not None:
#     244 		vectors.append(vec)
#
# File ~/Documents/python/VoltageDimentionalReduction/clean_code/Utilities/reader.py:60, in readvec(file, is_binary)
#      58 	print(line)
#      59 	print('no of parts=', len(parts))
# ---> 60 	raise ParseException(parts)
#      62 try:
#      63 	label = parts[0]
#
# ParseException: ['']
