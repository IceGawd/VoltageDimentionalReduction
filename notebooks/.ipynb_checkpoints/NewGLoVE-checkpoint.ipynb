# %%
import sys
import os
sys.path.append(os.path.abspath("../clean_code/"))

# %%
from Visualization import generalVisualization
from Visualization import gloveVisuals
from Visualization import visualHelpers
from Utilities import config

import pickle
import select_landmarks_MI
import importlib
import voltagemap
import setofpoints
import main
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.manifold import MDS
from sklearn.datasets import fetch_openml

# %%
config.params['file_path']= '../../Voltage_Data/glove/shuffled_output.txt'
config.params['split_char']= ' '
config.params['normalize_vecs'] = True

config.params['max_centroids']= 1000
config.params['init_size']= 5000
config.params['batch_size']= 1000
config.params['kmeans_output']= '../../Voltage_Temp/Results/glove.npy'
config.params['k']=2
config.params['r']=1
config.params['alpha']=0.1
config.params['equalize_centroids']=False
config.params['NoOfLandmarks']=10
config.params['DepthOfLandmarkSearch']=100

# %%
data_to_save = main.main()
# Out:
# Read 5000 vectors
# Estimated max pairwise distance squared, FAISS) = 2.9098
#  Estimated minimum distance squared = 0.0000
# 10 vectors in index after adding initial centroid
# Read 6000 vectors
# number of centroids: 557, max_centroids: 1000
# Read 7000 vectors
# number of centroids: 1000, max_centroids: 1000
# Reached maximum number of centroids: 1000
# Read 8000 vectors
# refining vectors
# sorted_sizes=[63 38 14 14 13]
# too_small=547, rms=0.04458313810547017, finished=False
#
# refining vectors
# sorted_sizes=[60 34 15 14 13]
# too_small=545, rms=0.041007138137724046, finished=False
#
# refining vectors
# sorted_sizes=[59 33 14 14 13]
# too_small=541, rms=0.03794122052187731, finished=False
#
# refining vectors
# sorted_sizes=[59 33 14 14 13]
# too_small=541, rms=0.03506369969979998, finished=False
#
# refining vectors
# sorted_sizes=[58 33 15 14 13]
# too_small=541, rms=0.03254715936712405, finished=False
#
# refining vectors
# sorted_sizes=[58 33 15 14 13]
# too_small=539, rms=0.03044124523246396, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=536, rms=0.028663082248449274, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=536, rms=0.02699661814608859, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=531, rms=0.025798573259604704, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=531, rms=0.024538147381616107, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=529, rms=0.023562176291595873, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=528, rms=0.022691502879984515, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=525, rms=0.02205807766334711, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=525, rms=0.021381380057015793, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=521, rms=0.02101150600145987, finished=False
#
# refining vectors
# sorted_sizes=[57 33 15 14 13]
# too_small=519, rms=0.020598197607397544, finished=False
#
# refining vectors
# sorted_sizes=[56 33 16 14 13]
# too_small=518, rms=0.02020864731644284, finished=False
#
# refining vectors
# sorted_sizes=[56 33 16 14 13]
# too_small=512, rms=0.020124901544246974, finished=False
#
# refining vectors
# sorted_sizes=[56 33 16 14 13]
# too_small=512, rms=0.01977249130655984, finished=False
#
# refining vectors
# sorted_sizes=[56 30 16 15  9]
# too_small=505, rms=0.01989724245858332, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=504, rms=0.019693195207715963, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=501, rms=0.019638410062742487, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01949177807319429, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01932429410382376, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01918756047067986, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01907608785053717, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018985315174582754, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01891146990208392, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018851443196662366, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018802681062083, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018763090942681578, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018730961485513172, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018704896168549267, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018683756649003277, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018666616120221483, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018652720669369655, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018641457786763682, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018632329821106595, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01862493292014212, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018618939315149817, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018614083044088084, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01861014855365693, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018606961011539858, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018604378693357456, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01860228668569748, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01860059208024174, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018599219244482622, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018598107222614704, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018597206414476226, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859647673340013, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018595885676876107, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018595406881106002, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018595019097672617, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018594705020643237, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859445054110806, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018594244398763213, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018594077469278665, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593942202645066, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859383266600363, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859374392822252, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859367208596337, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859361379602325, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859356666878152, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593528476555283, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593497611960243, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593472513389536, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593452268522853, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593435755574473, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593422485330573, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.0185934117028094, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593402909271757, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859339583485562, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859339012413664, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859338545731568, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859338171533482, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859337868145596, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859337620096503, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593374193083344, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.01859337260251248, finished=False
#
# refining vectors
# sorted_sizes=[55 21 16 15  9]
# too_small=500, rms=0.018593371248288696, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.01859477739664939, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.01859461315678686, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.01859448015323576, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.018594372316342304, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.018594285091835503, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.01859421432895184, finished=False
#
# refining vectors
# sorted_sizes=[54 21 16 15 10]
# too_small=500, rms=0.018594157082850768, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018594008279842554, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859392618649595, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859385962283428, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593805732742504, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859376205062278, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593726728223584, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859369803990421, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593674878727682, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593656044191123, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859364083539012, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593628474956957, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859361851754522, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.0185936104303094, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859360386522621, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859359851037688, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593594255841586, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593590788283897, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593587958773288, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593585670076365, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593583812473707, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593582287230803, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859358106920372, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593580123876588, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593579307179975, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593578675410095, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357814869627, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593577697263514, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593577411868976, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593577063961402, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357685074545, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576684551506, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357656067174, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576458747832, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576355292848, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576305084486, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357618915759, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576157773146, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576098228835, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576034000706, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576062132817, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593576027662432, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357602137321, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575977522946, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575988461102, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575972793257, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575946171444, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575949291875, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575944587888, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575919537024, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575896052702, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575897613592, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.0185935758976101, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575930477783, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575944562894, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357593516953, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575917950234, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575928905974, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357592577459, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575928904458, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575913251316, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575900728816, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575891336943, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575894467248, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357588194495, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357591951111, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.0185935759069889, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575916380396, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575910119283, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575916380296, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357593203289, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357591638024, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.0185935759257718, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357592264126, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357591951073, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.0185935759163802, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575919510722, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575906988617, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575897597043, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.01859357591011914, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575932032817, finished=False
#
# refining vectors
# sorted_sizes=[53 21 17 15 10]
# too_small=500, rms=0.018593575932032817, finished=True
# Read 9000 vectors
# refining vectors
# sorted_sizes=[425  90  61  53  48]
# too_small=906, rms=0.0172839864978892, finished=False
#
# refining vectors
# sorted_sizes=[386  94  60  54  49]
# too_small=906, rms=0.016297139825456775, finished=False
#
# refining vectors
# sorted_sizes=[351  89  61  56  52]
# too_small=906, rms=0.015498961124693896, finished=False
#
# refining vectors
# sorted_sizes=[307  92  61  57  53]
# too_small=905, rms=0.014908098161920855, finished=False
#
# refining vectors
# sorted_sizes=[272  89  62  58  52]
# too_small=903, rms=0.014506222139917388, finished=False
#
# refining vectors
# sorted_sizes=[225  89  63  62  50]
# too_small=902, rms=0.014110171099850022, finished=False
#
# refining vectors
# sorted_sizes=[197  82  63  62  49]
# too_small=899, rms=0.013957822347918905, finished=False
#
# refining vectors
# sorted_sizes=[167  72  63  61  49]
# too_small=894, rms=0.014091513676566855, finished=False
#
# refining vectors
# sorted_sizes=[143  67  61  60  49]
# too_small=889, rms=0.014185514026787248, finished=False
#
# refining vectors
# sorted_sizes=[118  65  60  58  48]
# too_small=886, rms=0.014117670390126048, finished=False
#
# refining vectors
# sorted_sizes=[113  64  58  55  44]
# too_small=877, rms=0.014634640780729319, finished=False
#
# refining vectors
# sorted_sizes=[100  63  57  50  37]
# too_small=866, rms=0.015309531375078492, finished=False
#
# refining vectors
# sorted_sizes=[85 54 52 46 33]
# too_small=861, rms=0.015414446171984982, finished=False
#
# refining vectors
# sorted_sizes=[80 55 50 42 32]
# too_small=853, rms=0.01579574459734694, finished=False
#
# refining vectors
# sorted_sizes=[56 54 50 41 29]
# too_small=844, rms=0.016103842436680095, finished=False
#
# refining vectors
# sorted_sizes=[50 49 46 41 29]
# too_small=832, rms=0.016691875639042814, finished=False
#
# refining vectors
# sorted_sizes=[46 45 45 41 29]
# too_small=825, rms=0.016739341741088824, finished=False
#
# refining vectors
# sorted_sizes=[45 45 41 41 29]
# too_small=815, rms=0.01704645188525892, finished=False
#
# refining vectors
# sorted_sizes=[45 42 40 39 29]
# too_small=801, rms=0.017603257974491787, finished=False
#
# refining vectors
# sorted_sizes=[45 42 37 34 29]
# too_small=791, rms=0.017817861801050078, finished=False
#
# refining vectors
# sorted_sizes=[45 40 37 32 29]
# too_small=781, rms=0.018074450107079882, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=775, rms=0.01797392207784062, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=775, rms=0.01755021471198647, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=775, rms=0.017198767678911552, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=773, rms=0.017022278575689328, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=770, rms=0.01697851439448489, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 29]
# too_small=769, rms=0.016819339584736172, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 28]
# too_small=746, rms=0.01810838975123051, finished=False
#
# refining vectors
# sorted_sizes=[44 40 37 31 28]
# too_small=745, rms=0.017834920468858304, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=740, rms=0.01787334091624821, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=739, rms=0.0176017622216292, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=732, rms=0.01768716791007791, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=729, rms=0.017561056807423956, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=726, rms=0.01746498636958093, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36 31 28]
# too_small=720, rms=0.017528192366216215, finished=False
#
# refining vectors
# sorted_sizes=[44 40 36
finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544853676141, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345448349206525, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345448156351616, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544795574741, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544781581037, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544781376234, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447675332145, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447612268286, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447551219828, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544749059951, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447462435733, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447432370484, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.0183454474027322, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544740615292, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447389726405, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447418047608, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447413017184, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447347371816, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447314472525, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447293502386, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544735569429, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732958696, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447337233013, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447335715793, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.0183454473011712, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447344594812, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447334268638, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447339959863, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447283904078, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447348517768, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447344996192, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447309811948, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447307996348, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544730622408, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447336215515, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733450684, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447289987486, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447305771354, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447305705986, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544734055451, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733733862, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544731509362, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447327756687, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447297591376, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733088777, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447327699663, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447308650096, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447337195845, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544730863186, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447308625196, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447356212803, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447318134, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447316543976, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447322886784, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447310192938, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447326055333, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544731018942, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447316533862, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.0183454473070142, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447300667606, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732129054, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732128997, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447340326705, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447330807733, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447343498897, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732128859, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447333979876, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447318115396, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447311769552, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.0183454473276338, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447337152345, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.0183454473371523, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447340325137, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733397938, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447333979366, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732128789, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732446075, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544732128788, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.018345447337152217, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544734349795, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733715221, finished=False
#
# refining vectors
# sorted_sizes=[18 18 17 16 15]
# too_small=496, rms=0.01834544733715221, finished=True
# Read 10000 vectors
# refining vectors
# sorted_sizes=[178 136 100  81  66]
# too_small=930, rms=0.014406905612869126, finished=False
#
# refining vectors
# sorted_sizes=[164 129  99  81  64]
# too_small=930, rms=0.0137195990074072, finished=False
#
# refining vectors
# sorted_sizes=[155 128  94  80  65]
# too_small=929, rms=0.013255902221457843, finished=False
#
# refining vectors
# sorted_sizes=[149 126  92  78  64]
# too_small=929, rms=0.012757276054072685, finished=False
#
# refining vectors
# sorted_sizes=[140 124  91  76  61]
# too_small=929, rms=0.012414538649325225, finished=False
#
# refining vectors
# sorted_sizes=[135 124  89  75  60]
# too_small=928, rms=0.012193608633902042, finished=False
#
# refining vectors
# sorted_sizes=[125 118  88  76  60]
# too_small=927, rms=0.012020471369538339, finished=False
#
# refining vectors
# sorted_sizes=[121 101  87  77  59]
# too_small=924, rms=0.01211000388958119, finished=False
#
# refining vectors
# sorted_sizes=[102  87  86  75  58]
# too_small=919, rms=0.01250544849898661, finished=False
#
# refining vectors
# sorted_sizes=[93 82 72 66 58]
# too_small=914, rms=0.012871874581983894, finished=False
#
# refining vectors
# sorted_sizes=[88 70 69 61 56]
# too_small=905, rms=0.013625893682068407, finished=False
#
# refining vectors
# sorted_sizes=[80 70 58 58 48]
# too_small=896, rms=0.01423529821541291, finished=False
#
# refining vectors
# sorted_sizes=[69 67 53 53 46]
# too_small=888, rms=0.014672072159497713, finished=False
#
# refining vectors
# sorted_sizes=[69 67 52 50 43]
# too_small=878, rms=0.015190080828007529, finished=False
#
# refining vectors
# sorted_sizes=[69 65 48 44 41]
# too_small=870, rms=0.015572882811102343, finished=False
#
# refining vectors
# sorted_sizes=[68 58 47 43 40]
# too_small=861, rms=0.016002678592196225, finished=False
#
# refining vectors
# sorted_sizes=[66 54 45 39 38]
# too_small=847, rms=0.01663027072041532, finished=False
#
# refining vectors
# sorted_sizes=[54 52 38 38 35]
# too_small=838, rms=0.016972831011663508, finished=False
#
# refining vectors
# sorted_sizes=[50 46 38 36 34]
# too_small=826, rms=0.017355550201158258, finished=False
#
# refining vectors
# sorted_sizes=[50 44 38 35 34]
# too_small=822, rms=0.017188609856414794, finished=False
#
# refining vectors
# sorted_sizes=[50 44 38 35 34]
# too_small=807, rms=0.017807143427297157, finished=False
#
# refining vectors
# sorted_sizes=[50 44 38 33 32]
# too_small=793, rms=0.01821585045457356, finished=False
#
# refining vectors
# sorted_sizes=[43 42 34 30 30]
# too_small=779, rms=0.018726259379921954, finished=False
#
# refining vectors
# sorted_sizes=[38 31 31 30 27]
# too_small=773, rms=0.018707672938491265, finished=False
#
# refining vectors
# sorted_sizes=[30 29 28 27 27]
# too_small=767, rms=0.018685997401666883, finished=False
#
# refining vectors
# sorted_sizes=[29 29 28 27 27]
# too_small=764, rms=0.018509158596572553, finished=False
#
# refining vectors
# sorted_sizes=[29 28 27 27 27]
# too_small=764, rms=0.018143187281891345, finished=False
#
# refining vectors
# sorted_sizes=[29 28 27 27 27]
# too_small=758, rms=0.01826183191436904, finished=False
#
# refining vectors
# sorted_sizes=[28 28 27 27 27]
# too_small=757, rms=0.01803570805705925, finished=False
#
# refining vectors
# sorted_sizes=[28 28 27 27 26]
# too_small=754, rms=0.017958275721175875, finished=False
#
# refining vectors
# sorted_sizes=[28 28 27 27 26]
# too_small=752, rms=0.017851949186749132, finished=False
#
# refining vectors
# sorted_sizes=[28 26 25 25 24]
# too_small=731, rms=0.018824605925758738, finished=False
#
# refining vectors
# sorted_sizes=[28 25 23 23 23]
# too_small=730, rms=0.01855452352881549, finished=False
#
# refining vectors
# sorted_sizes=[28 25 23 23 22]
# too_small=721, rms=0.01871314051746388, finished=False
#
# refining vectors
# sorted_sizes=[26 25 23 22 22]
# too_small=712, rms=0.018909785876799323, finished=False
#
# refining vectors
# sorted_sizes=[22 22 21 21 19]
# too_small=672, rms=0.020904055640916484, finished=False
#
# refining vectors
# sorted_sizes=[21 20 19 19 18]
# too_small=658, rms=0.02115183994272403, finished=False
#
# refining vectors
# sorted_sizes=[20 20 18 18 18]
# too_small=647, rms=0.021210088170042034, finished=False
#
# refining vectors
# sorted_sizes=[20 20 18 18 16]
# too_small=637, rms=0.021198538599777807, finished=False
#
# refining vectors
# sorted_sizes=[20 19 18 18 16]
# too_small=632, rms=0.02091939945624309, finished=False
#
# refining vectors
# sorted_sizes=[20 18 18 18 16]
# too_small=624, rms=0.02087370336520361, finished=False
#
# refining vectors
# sorted_sizes=[20 18 18 16 16]
# too_small=613, rms=0.021062469365849178, finished=False
#
# refining vectors
# sorted_sizes=[19 18 16 16 15]
# too_small=605, rms=0.020998248866522504, finished=False
#
# refining vectors
# sorted_sizes=[18 16 16 15 15]
# too_small=599, rms=0.020875112593766364, finished=False
#
# refining vectors
# sorted_sizes=[18 16 16 15 15]
# too_small=599, rms=0.020455633718031056, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 14]
# too_small=590, rms=0.020594920256966975, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 14]
# too_small=587, rms=0.020386880507730715, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=583, rms=0.020288932444911603, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=574, rms=0.02048499697678231, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=567, rms=0.020526876292243503, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=564, rms=0.02036451289324306, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=559, rms=0.02035236546246424, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=559, rms=0.02007655754871232, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=557, rms=0.01995604678621129, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=557, rms=0.019749799894044885, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=557, rms=0.019581147481522884, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=556, rms=0.019490924851598878, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=555, rms=0.01941972162035286, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=548, rms=0.019680069929711445, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=525, rms=0.02062629389807847, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=525, rms=0.02028712643981341, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=524, rms=0.02006332302458886, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=523, rms=0.01988322487464907, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=523, rms=0.019672789550007317, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=523, rms=0.019500672243558777, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# too_small=522, rms=0.019413489082991644, finished=False
#
# refining vectors
# sorted_sizes=[18 16 14 14 13]
# ...
#
# refining vectors
# sorted_sizes=[12 11 11  8  8]
# too_small=500, rms=0.01977176555916745, finished=False
#
# refining vectors
# sorted_sizes=[12 11 11  8  8]
# too_small=500, rms=0.019771765559167445, finished=False
#
# refining vectors
# sorted_sizes=[12 11 11  8  8]
# too_small=500, rms=0.019771765559167445, finished=True
# Read 14000 vectors
# refining vectors
# sorted_sizes=[102  67  67  58  57]
# too_small=893, rms=0.01816601172366058, finished=False
#
# refining vectors
# sorted_sizes=[97 67 66 57 55]
# too_small=893, rms=0.017129667092169745, finished=False
#
# refining vectors
# sorted_sizes=[95 66 64 56 54]
# too_small=893, rms=0.016235148313870646, finished=False
#
# refining vectors
# sorted_sizes=[92 66 64 56 53]
# too_small=893, rms=0.015530464577366673, finished=False
#
# refining vectors
# sorted_sizes=[91 67 61 56 53]
# too_small=893, rms=0.014948076560246815, finished=False
#
# refining vectors
# sorted_sizes=[91 66 58 57 51]
# too_small=892, rms=0.014558889344984074, finished=False
#
# refining vectors
# sorted_sizes=[92 66 56 55 51]
# too_small=891, rms=0.014220921415623011, finished=False
#
# refining vectors
# sorted_sizes=[91 66 56 53 51]
# too_small=891, rms=0.01382418418649656, finished=False
#
# refining vectors
# sorted_sizes=[87 66 56 53 52]
# too_small=890, rms=0.013599525469232206, finished=False
#
# refining vectors
# sorted_sizes=[82 64 55 52 52]
# too_small=885, rms=0.01381132384201324, finished=False
#
# refining vectors
# sorted_sizes=[79 62 52 48 48]
# too_small=879, rms=0.01412245555277644, finished=False
#
# refining vectors
# sorted_sizes=[78 61 52 47 46]
# too_small=872, rms=0.014499375374315622, finished=False
#
# refining vectors
# sorted_sizes=[67 62 51 46 43]
# too_small=866, rms=0.014757978005504154, finished=False
#
# refining vectors
# sorted_sizes=[62 59 45 44 41]
# too_small=859, rms=0.015028349780945126, finished=False
#
# refining vectors
# sorted_sizes=[58 56 44 39 38]
# too_small=848, rms=0.015686905866885103, finished=False
#
# refining vectors
# sorted_sizes=[51 49 43 38 36]
# too_small=837, rms=0.016245102531728835, finished=False
#
# refining vectors
# sorted_sizes=[50 49 42 37 35]
# too_small=820, rms=0.017081529451838846, finished=False
#
# refining vectors
# sorted_sizes=[47 43 42 37 35]
# too_small=814, rms=0.01710760746464112, finished=False
#
# refining vectors
# sorted_sizes=[43 40 39 33 32]
# too_small=805, rms=0.017357201565359526, finished=False
#
# refining vectors
# sorted_sizes=[44 35 34 32 31]
# too_small=795, rms=0.01769328034625275, finished=False
#
# refining vectors
# sorted_sizes=[44 35 34 32 31]
# too_small=784, rms=0.01805568427651307, finished=False
#
# refining vectors
# sorted_sizes=[43 35 34 32 30]
# too_small=780, rms=0.017929648753296928, finished=False
#
# refining vectors
# sorted_sizes=[43 35 34 32 29]
# too_small=772, rms=0.018114586273247565, finished=False
#
# refining vectors
# sorted_sizes=[41 32 30 27 27]
# too_small=765, rms=0.01824185010136092, finished=False
#
# refining vectors
# sorted_sizes=[41 29 27 27 24]
# too_small=763, rms=0.018038723531180197, finished=False
#
# refining vectors
# sorted_sizes=[41 27 25 24 23]
# too_small=757, rms=0.018204310780197352, finished=False
#
# refining vectors
# sorted_sizes=[35 27 24 24 20]
# too_small=733, rms=0.019265166470556646, finished=False
#
# refining vectors
# sorted_sizes=[29 27 24 24 18]
# too_small=724, rms=0.019401956819974437, finished=False
#
# refining vectors
# sorted_sizes=[29 27 24 23 18]
# too_small=717, rms=0.019436012566625867, finished=False
#
# refining vectors
# sorted_sizes=[29 26 23 22 18]
# too_small=712, rms=0.01930843178211102, finished=False
#
# refining vectors
# sorted_sizes=[29 23 22 22 18]
# too_small=709, rms=0.019102827274993798, finished=False
#
# refining vectors
# sorted_sizes=[29 22 21 21 18]
# too_small=705, rms=0.019028819593434408, finished=False
#
# refining vectors
# sorted_sizes=[27 22 21 20 18]
# too_small=697, rms=0.01914334106629403, finished=False
#
# refining vectors
# sorted_sizes=[25 22 21 20 18]
# too_small=693, rms=0.01901745148503333, finished=False
#
# refining vectors
# sorted_sizes=[25 22 21 20 18]
# too_small=692, rms=0.01876645696704935, finished=False
#
# refining vectors
# sorted_sizes=[25 22 20 20 18]
# too_small=688, rms=0.018747684009538752, finished=False
#
# refining vectors
# sorted_sizes=[25 22 20 19 18]
# too_small=684, rms=0.01878118845638574, finished=False
#
# refining vectors
# sorted_sizes=[24 22 20 19 18]
# too_small=669, rms=0.019428640915305283, finished=False
#
# refining vectors
# sorted_sizes=[22 22 20 19 18]
# too_small=658, rms=0.019533455545756452, finished=False
#
# refining vectors
# sorted_sizes=[22 19 18 17 14]
# too_small=632, rms=0.020838502288540253, finished=False
#
# refining vectors
# sorted_sizes=[22 19 18 17 13]
# too_small=623, rms=0.020885376014249734, finished=False
#
# refining vectors
# sorted_sizes=[22 18 17 17 13]
# too_small=616, rms=0.02082515316151958, finished=False
#
# refining vectors
# sorted_sizes=[21 18 17 15 13]
# too_small=604, rms=0.021065075007050342, finished=False
#
# refining vectors
# sorted_sizes=[19 18 17 14 13]
# too_small=600, rms=0.02084678299179661, finished=False
#
# refining vectors
# sorted_sizes=[19 18 17 14 13]
# too_small=591, rms=0.020916315284534918, finished=False
#
# refining vectors
# sorted_sizes=[18 17 15 14 13]
# too_small=586, rms=0.020851946016219532, finished=False
#
# refining vectors
# sorted_sizes=[18 17 15 13 11]
# too_small=580, rms=0.020838939026903314, finished=False
#
# refining vectors
# sorted_sizes=[18 17 15 13 11]
# too_small